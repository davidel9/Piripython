# %% [markdown]
# # Practical — Working with the filesystem with `pathlib`
#
# In these exercises, use `Path` objects to inspect, search, create, and reorganize files and folders.
#
# > Replace the example paths with paths that exist on your machine.

# %% [markdown]
# ## Exercise 1 — Basic path inspection
#
# Create a `Path` object pointing to a file of your choice on your machine, then print:
#
# - whether it exists
# - its name
# - its stem
# - its suffix
# - its parent

# %%
from pathlib import Path

p = Path("/Users/davide/Pictures/Marocco/itinerario-marocco-10-giorni.png")

print(p.exists())
print(p.name)
print(p.stem)
print(p.suffix)
print(p.parent)
# Out:
# True
# itinerario-marocco-10-giorni.png
# itinerario-marocco-10-giorni
# .png
# /Users/davide/Pictures/Marocco

# %% [markdown]
# ## Exercise 2 — File or folder?
#
# Create two `Path` objects:
#
# - one pointing to a file
# - one pointing to a folder
#
# For each path, print whether it is a directory.

# %%
from pathlib import Path

file_path = Path("/Users/davide/Pictures/Marocco/itinerario-marocco-10-giorni.png")
folder_path = Path("/Users/davide/Pictures/Marocco")

print(file_path.is_dir())
print(folder_path.is_dir())
# Out:
# False
# True

# %% [markdown]
# ## Exercise 3 — List all notebook files
#
# Given a folder path, print all `.ipynb` files in alphabetical order.

# %%
from pathlib import Path

folder = Path("/Users/davide/Documents/GitHub/PythonCourse/Assignement")

for path in sorted(folder.glob("*.ipynb")):
    print(path)
# Out:
# /Users/davide/Documents/GitHub/PythonCourse/Assignement/Practical_p.1_File_System.ipynb

# %% [markdown]
# ## Exercise 4 — Count files by extension
#
# Given a folder, count how many files end with:
#
# - `.py`
# - `.ipynb`
# - `.md`
#
# Print the three counts.

# %%
from pathlib import Path

folder = Path("/Users/davide/Pictures")

png_count = 0
jpg_count = 0
psd_count = 0

for path in folder.glob("*"):
    if path.suffix == ".png":
        png_count += 1
    elif path.suffix == ".jpg":
        jpg_count += 1
    elif path.suffix == ".psd":
        psd_count += 1

print("png:", png_count)
print("jpg", jpg_count)
print("psd:", psd_count)
# Out:
# png: 23
# jpg 15
# psd: 6

# %% [markdown]
# ## Exercise 5 — Print only subfolders
#
# Given a folder, print first the paths that are directories, then the paths that are not directories

# %%
from pathlib import Path

folder = Path("/Users/davide/Pictures/Marocco")

# Directory
for path in folder.glob("*"):
    if path.is_dir():
        print(path)

# File
for path in folder.glob("*"):
    if not path.is_dir():
        print(path)
# Out:
# /Users/davide/Pictures/Marocco/Foto
# /Users/davide/Pictures/Marocco/9
# /Users/davide/Pictures/Marocco/7
# /Users/davide/Pictures/Marocco/6
# /Users/davide/Pictures/Marocco/1
# /Users/davide/Pictures/Marocco/8
# /Users/davide/Pictures/Marocco/4
# /Users/davide/Pictures/Marocco/3
# /Users/davide/Pictures/Marocco/2
# /Users/davide/Pictures/Marocco/5
# /Users/davide/Pictures/Marocco/itinerario-marocco-10-giorni.png
# /Users/davide/Pictures/Marocco/.DS_Store

# %% [markdown]
# ## Exercise 6 — Recursive notebook search
#
# Search recursively inside a course folder and print all `.ipynb` files found in all subfolders.
#
# Then print the total number of notebooks found.

# %%
from pathlib import Path

course_folder = Path("/Users/davide/Pictures/Marocco")

count = 0

for path in course_folder.rglob("*.jpg"):
    print(path)
    count += 1

print("Total images:", count)
# Out:
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_100925462.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_102056266.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_191459735.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_172820881.NIGHT.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_170018070.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250710_160448607.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_095453757.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_182608965.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_150535375.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_100914657.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185730441.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_150054637.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185707616.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_140125925.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_100927298.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250703_161613966.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_095510912.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_172040930.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185654513.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250703_225459518.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_101923471.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185753644.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185757190.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_182545591.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_105552452.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_175358132.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_142027679.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250708_084847152.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_194156699.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_152507059.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250709_132133605.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_174510155.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_174216030.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_192700910.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250708_132538382.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_085838984.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185802501.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250711_164515774.PORTRAIT.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185714784.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_100928733.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185710441.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250710_160558091.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_105534978.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250708_084850544.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_172044734.jpg
# /Users/davide/Pictures/Marocco/Foto/IMG-20250706-WA0040.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_080635484.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_174222978.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_100916615.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250710_105331242.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_190416602.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185715309.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185729237.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_092656878.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_140059239.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_145801981.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185725279.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250708_085311519.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_113514526.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_191126524.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_125411936.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250707_191504821.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_141308252.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250708_085640164.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_182216797.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250710_160334599.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_182145788.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250704_192933760.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250705_174236757.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185752433.jpg
# /Users/davide/Pictures/Marocco/Foto/PXL_20250706_185716072.jpg
# /Users/davide/Pictures/Marocco/Foto/Camera/Marocco edit camera/IMG-20250706-WA0040.jpg
# Total images: 72

# %% [markdown]
# ## Exercise 7 — Build paths safely
#
# Starting from a base course folder, create paths for:
#
# - `lectures`
# - `practicals`
# - `data/raw`
#
# using the `/` operator, not string concatenation.
#
# Then print all of them.

# %%
from pathlib import Path

base = Path("/Users/davide/Documents/GitHub/PythonCourse")

lectures = base / "lectures"
practicals = base / "practicals"
raw_data = base / "data" / "raw"

print(lectures)
print(practicals)
print(raw_data)
# Out:
# /Users/davide/Documents/GitHub/PythonCourse/lectures
# /Users/davide/Documents/GitHub/PythonCourse/practicals
# /Users/davide/Documents/GitHub/PythonCourse/data/raw

# %% [markdown]
# ## Exercise 8 — Create a nested folder structure
#
# Create the following structure inside a base folder:
#
# - `results/`
# - `results/figures/`
# - `results/tables/`
#
# Do it programmatically with `mkdir()`.

# %%
from pathlib import Path

base = Path("/Users/davide/Documents/GitHub/PythonCourse")

figures_path = base / "results" / "figures"
tables_path = base / "results" / "tables"

figures_path.mkdir(parents=True, exist_ok=True)
tables_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Exercise 9 — Move matching files
#
# Inside a folder, move all `.txt` files into a subfolder called `text_files`.
#
# If the destination folder does not exist, create it first.

# %%
from pathlib import Path

folder = Path("/Users/davide/Pictures/Marocco")
destination = folder / "text_files"

destination.mkdir(exist_ok=True)

for path in folder.glob("*.txt"):
    if not path.is_dir():
        path.rename(destination / path.name)

# %% [markdown]
# ## Exercise 10 — Organize files by prefix
#
# Suppose a folder contains files with names such as:
#
# - `sub01_session1_data.csv`
# - `sub01_session2_data.csv`
# - `sub02_session1_data.csv`
#
# Write code that moves each file into a folder structure like:
#
# - `sub01/session1/`
# - `sub01/session2/`
# - `sub02/session1/`
#
# Use the filename (without extension) and split it on `"_"`.

# %%
from pathlib import Path

data_folder = Path("/Users/davide/Documents/data")
new_root = Path("/Users/davide/Documents/organized")
new_root.mkdir(exist_ok=True)

for file in data_folder.glob("*.csv"):
    subject, session, _ = file.stem.split("_")
    target_folder = new_root / subject / session
    target_folder.mkdir(exist_ok=True, parents=True)
    file.rename(target_folder / file.name)

# %% [markdown]
# ## Exercise 11 — Build a file inventory
#
# Given a folder, create a list of dictionaries where each dictionary contains:
#
# - `"name"`
# - `"suffix"`
# - `"is_dir"`
# - `"parent"`
#
# for every path in the folder.
#
# Then print the resulting list.

# %%
from pathlib import Path

folder = Path("/Users/davide/Pictures/Marocco")
inventory = []

for path in folder.glob("*"):
    info = {
        "name": path.name,
        "suffix": path.suffix,
        "is_dir": path.is_dir(),
        "parent": str(path.parent)
    }
    inventory.append(info)

print(inventory)

# %% [markdown]
# ## Exercise 12 —  Only files, sorted by suffix
#
# Given a folder:
#
# 1. collect only the files, not the subfolders
# 2. sort them by suffix
# 3. print their names

# %%
from pathlib import Path

folder = Path("/Users/davide/Pictures/Marocco")

files_only = []

for path in folder.glob("*"):
    if not path.is_dir():
        files_only.append(path)

for path in sorted(files_only, key=lambda p: p.suffix):
    print(path.name)
